# %% [markdown]
# # LECTURA Y ESCRITURA DE FICHEROS EN PANDAS
# ***
#
# En este notebook se explicarán los principales métodos de lectura y escritura de archivos excel, csv, txt y algunas funciones utiles de la la libreria pandas en python, ademas se realizará una exploración de los datos aplicando algunas funciones importantes de pandas.
#
# [1. Lectura de archivos excel, csv, txt, html](#1.-Lectura-de-archivos-excel,-csv,-txt,-html)<br>
# [2. Funciones básicas de lectura de ficheros](#2.-Funciones-básicas-de-lectura-de-ficheros)<br>
# [3. Funciones básicas de almacenamiento](#3.-Funciones-básicas-de-almacenamiento)<br>
# [4. Explorando nuestro DataFrame](#4.-Explorando-nuestro-DataFrame)<br>

# %%
# importar libreria
import pandas as pd
import xlrd
pd.__version__
# Out:
# '1.5.2'

# %% [markdown]
# ## <font color=#33A5FF>****1. Lectura de archivos excel, csv, txt, html****<tfont>

# %% [markdown]
# ### Descripción del las columnas del DataFrame

# %% [markdown]
# Para leer ficheros de excel puedes instalar en el anaconda Prom: **pip install xlrd**, seguido de ello puedes cargar el fichero titanic el cual contiene la siguiente información:

# %% [markdown]
# * **Id_Pasajero:** Id de cada pasajero.
#
# * **Survived:** esta característica tiene valor 0 y 1. 0 para no sobrevivido y 1 para sobrevivido.
#
# * **Clase:** Hay 3 clases: Clase 1, Clase 2 y Clase 3.
#
# * **Nombre:** Nombre del pasajero.
#
# * **Sexo:** Género del pasajero.
#
# * **Edad:** Edad del pasajero.
#
# * **Familiares:** numero de familiares del pasajero.
#
# * **Ticket:** Número de ticket del pasajero.
#
# * **Tarifa:** Indicando la tarifa.
#
# * **Cabina:** La cabina del pasajero.
#
# * **Embarcado:** La categoría embarcada.

# %%
# Espeficicar la ruta o dirección de los archivos
ruta = '/home/michel/Escritorio/Repositorios_git/Pandas_Curso/PANDAS-main/'

# %% [markdown]
# Leer datos archivos excel con extensión **--->** .xls, .xlsx

# %%
# Leer datos excel con ruta, en caso de que el archivo se encuentre en una ruta diferente
pd.read_excel(ruta+'titanic.xlsx')
# Out:
#      Id_Pasajero  Survived  Clase  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      3
# 889          890         1      1
# 890          891         0      3
#
#                                                 Nombre       Sexo  Edad  \
# 0                              Braund, Mr. Owen Harris  Masculino  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino  38.0
# 2                               Heikkinen, Miss. Laina   Femenino  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino  35.0
# 4                             Allen, Mr. William Henry  Masculino  35.0
# ..                                                 ...        ...   ...
# 886                              Montvila, Rev. Juozas  Masculino  27.0
# 887                       Graham, Miss. Margaret Edith   Femenino  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   Femenino   NaN
# 889                              Behr, Mr. Karl Howell  Masculino  26.0
# 890                                Dooley, Mr. Patrick  Masculino  32.0
#
#      Familiares           Tiquete  Tarifa Cabina Embarcado
# 0             0         A/5 21171    7.25    NaN         S
# 1             0          PC 17599   71.28    C85         C
# 2             0  STON/O2. 3101282    7.93    NaN         S
# 3             0            113803   53.10   C123         S
# 4             0            373450    8.05    NaN         S
# ..          ...               ...     ...    ...       ...
# 886           0            211536   13.00    NaN         S
# 887           0            112053   30.00    B42         S
# 888           2        W./C. 6607   23.45    NaN         S
# 889           0            111369   30.00   C148         C
# 890           0            370376    7.75    NaN         Q
#
# [891 rows x 11 columns]

# %%
# Leer datos excel si el archivo se encuentra dentro de la misma carpeta del notebook
df = pd.read_excel('titanic.xlsx', engine='openpyxl')
df
# Out:
#      Id_Pasajero  Survived  Clase  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      3
# 889          890         1      1
# 890          891         0      3
#
#                                                 Nombre       Sexo  Edad  \
# 0                              Braund, Mr. Owen Harris  Masculino  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino  38.0
# 2                               Heikkinen, Miss. Laina   Femenino  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino  35.0
# 4                             Allen, Mr. William Henry  Masculino  35.0
# ..                                                 ...        ...   ...
# 886                              Montvila, Rev. Juozas  Masculino  27.0
# 887                       Graham, Miss. Margaret Edith   Femenino  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   Femenino   NaN
# 889                              Behr, Mr. Karl Howell  Masculino  26.0
# 890                                Dooley, Mr. Patrick  Masculino  32.0
#
#      Familiares           Tiquete  Tarifa Cabina Embarcado
# 0             0         A/5 21171    7.25    NaN         S
# 1             0          PC 17599   71.28    C85         C
# 2             0  STON/O2. 3101282    7.93    NaN         S
# 3             0            113803   53.10   C123         S
# 4             0            373450    8.05    NaN         S
# ..          ...               ...     ...    ...       ...
# 886           0            211536   13.00    NaN         S
# 887           0            112053   30.00    B42         S
# 888           2        W./C. 6607   23.45    NaN         S
# 889           0            111369   30.00   C148         C
# 890           0            370376    7.75    NaN         Q
#
# [891 rows x 11 columns]

# %% [markdown]
# Leer datos archivos excel con extensión ---> **.csv**

# %%
# Leer archivos .csv
df = pd.read_csv('titanic.csv', sep=';', index_col=0)
df
# Out:
#              Survived  Clase  \
# Id_Pasajero
# 1                   0      3
# 2                   1      1
# 3                   1      3
# 4                   1      1
# 5                   0      3
# ...               ...    ...
# 887                 0      2
# 888                 1      1
# 889                 0      3
# 890                 1      1
# 891                 0      3
#
#                                                         Nombre       Sexo  \
# Id_Pasajero
# 1                                      Braund, Mr. Owen Harris  Masculino
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino
# 3                                       Heikkinen, Miss. Laina   Femenino
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino
# 5                                     Allen, Mr. William Henry  Masculino
# ...                                                        ...        ...
# 887                                      Montvila, Rev. Juozas  Masculino
# 888                               Graham, Miss. Margaret Edith   Femenino
# 889                   Johnston, Miss. Catherine Helen "Carrie"   Femenino
# 890                                      Behr, Mr. Karl Howell  Masculino
# 891                                        Dooley, Mr. Patrick  Masculino
#
#              Edad  Familiares           Tiquete  Tarifa Cabina Embarcado
# Id_Pasajero
# 1            22.0           0         A/5 21171    7.25    NaN         S
# 2            38.0           0          PC 17599   71.28    C85         C
# 3            26.0           0  STON/O2. 3101282    7.93    NaN         S
# 4            35.0           0            113803   53.10   C123         S
# 5            35.0           0            373450    8.05    NaN         S
# ...           ...         ...               ...     ...    ...       ...
# 887          27.0           0            211536   13.00    NaN         S
# 888          19.0           0            112053   30.00    B42         S
# 889           NaN           2        W./C. 6607   23.45    NaN         S
# 890          26.0           0            111369   30.00   C148         C
# 891          32.0           0            370376    7.75    NaN         Q
#
# [891 rows x 10 columns]

# %% [markdown]
# Leer datos archivos excel con extensión ---> **.txt**

# %%
# Leer archivos .txt
df = pd.read_csv('titanic.txt', sep=';', index_col=3)
df
# Out:
#                                                     Id_Pasajero  Survived  \
# Nombre
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Clase       Sexo  Edad  \
# Nombre
# Braund, Mr. Owen Harris                                 3  Masculino  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1   Femenino  38.0
# Heikkinen, Miss. Laina                                  3   Femenino  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1   Femenino  35.0
# Allen, Mr. William Henry                                3  Masculino  35.0
# ...                                                   ...        ...   ...
# Montvila, Rev. Juozas                                   2  Masculino  27.0
# Graham, Miss. Margaret Edith                            1   Femenino  19.0
# Johnston, Miss. Catherine Helen "Carrie"                3   Femenino   NaN
# Behr, Mr. Karl Howell                                   1  Masculino  26.0
# Dooley, Mr. Patrick                                     3  Masculino  32.0
#
#                                                     Familiares  \
# Nombre
# Braund, Mr. Owen Harris                                      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...           0
# Heikkinen, Miss. Laina                                       0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                 0
# Allen, Mr. William Henry                                     0
# ...                                                        ...
# Montvila, Rev. Juozas                                        0
# Graham, Miss. Margaret Edith                                 0
# Johnston, Miss. Catherine Helen "Carrie"                     2
# Behr, Mr. Karl Howell                                        0
# Dooley, Mr. Patrick                                          0
#
#                                                              Tiquete  Tarifa  \
# Nombre
# Braund, Mr. Owen Harris                                    A/5 21171    7.25
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599   71.28
# Heikkinen, Miss. Laina                              STON/O2. 3101282    7.93
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803   53.10
# Allen, Mr. William Henry                                      373450    8.05
# ...                                                              ...     ...
# Montvila, Rev. Juozas                                         211536   13.00
# Graham, Miss. Margaret Edith                                  112053   30.00
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607   23.45
# Behr, Mr. Karl Howell                                         111369   30.00
# Dooley, Mr. Patrick                                           370376    7.75
#
#                                                    Cabina Embarcado
# Nombre
# Braund, Mr. Owen Harris                               NaN         S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    C85         C
# Heikkinen, Miss. Laina                                NaN         S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         C123         S
# Allen, Mr. William Henry                              NaN         S
# ...                                                   ...       ...
# Montvila, Rev. Juozas                                 NaN         S
# Graham, Miss. Margaret Edith                          B42         S
# Johnston, Miss. Catherine Helen "Carrie"              NaN         S
# Behr, Mr. Karl Howell                                C148         C
# Dooley, Mr. Patrick                                   NaN         Q
#
# [891 rows x 10 columns]

# %% [markdown]
# Leer datos de archivos html --> **.html**

# %%
# Leer archivo titanic
df = pd.read_html('titanic.html')
df[0]
# RECUERDA , Pandas en los archivos html, lee las tablas contenidos en el file, usamos el indice para acceder a ellas.
# Out:
#      Unnamed: 0  Id_Pasajero  Survived  Clase  \
# 0             0            1         0      3
# 1             1            2         1      1
# 2             2            3         1      3
# 3             3            4         1      1
# 4             4            5         0      3
# ..          ...          ...       ...    ...
# 886         886          887         0      2
# 887         887          888         1      1
# 888         888          889         0      3
# 889         889          890         1      1
# 890         890          891         0      3
#
#                                                 Nombre       Sexo  Edad  \
# 0                              Braund, Mr. Owen Harris  Masculino  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino  38.0
# 2                               Heikkinen, Miss. Laina   Femenino  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino  35.0
# 4                             Allen, Mr. William Henry  Masculino  35.0
# ..                                                 ...        ...   ...
# 886                              Montvila, Rev. Juozas  Masculino  27.0
# 887                       Graham, Miss. Margaret Edith   Femenino  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   Femenino   NaN
# 889                              Behr, Mr. Karl Howell  Masculino  26.0
# 890                                Dooley, Mr. Patrick  Masculino  32.0
#
#      Familiares           Tiquete  Tarifa Cabina Embarcado
# 0             0         A/5 21171    7.25    NaN         S
# 1             0          PC 17599   71.28    C85         C
# 2             0  STON/O2. 3101282    7.93    NaN         S
# 3             0            113803   53.10   C123         S
# 4             0            373450    8.05    NaN         S
# ..          ...               ...     ...    ...       ...
# 886           0            211536   13.00    NaN         S
# 887           0            112053   30.00    B42         S
# 888           2        W./C. 6607   23.45    NaN         S
# 889           0            111369   30.00   C148         C
# 890           0            370376    7.75    NaN         Q
#
# [891 rows x 12 columns]

# %%
# leer archivo desde pagina web
df = pd.read_html('https://es.wikipedia.org/wiki/Luisiana')
df[3]
# Esta web contiene 5 tablas a las que accedemos por el indice
# Out:
#                         Demografía de Luisiana.[10]​  \
#                                             Por raza
# 0                             2000 (población total)
# 1                                2000 (solo hispana)
# 2                             2005 (población total)
# 3                                2005 (solo hispana)
# 4               Incremento 2000–05 (población total)
# 5               Incremento 2000–05 (solo no hispana)
# 6                  Incremento 2000–05 (solo hispana)
# 7  * AIAN es nativo americano o nativo de Alaska;...
#
#                                                       \
#                                               Blanca
# 0                                            65,39 %
# 1                                             2,09 %
# 2                                            64,77 %
# 3                                             2,52 %
# 4                                             0,26 %
# 5                                            -0,47 %
# 6                                            22,23 %
# 7  * AIAN es nativo americano o nativo de Alaska;...
#
#                                                       \
#                                                Negra
# 0                                            32,94 %
# 1                                             0,28 %
# 2                                            33,47 %
# 3                                             0,27 %
# 4                                             2,86 %
# 5                                             2,89 %
# 6                                            -1,03 %
# 7  * AIAN es nativo americano o nativo de Alaska;...
#
#                                                       \
#                                                AIAN*
# 0                                             0,96 %
# 1                                             0,06 %
# 2                                             0,97 %
# 3                                             0,06 %
# 4                                             2,26 %
# 5                                             2,47 %
# 6                                            -8,78 %
# 7  * AIAN es nativo americano o nativo de Alaska;...
#
#                                                       \
#                                             Asiática
# 0                                             1,45 %
# 1                                             0,03 %
# 2                                             1,60 %
# 3                                             0,03 %
# 4                                            11,98 %
# 5                                            12,11 %
# 6                                             6,41 %
# 7  * AIAN es nativo americano o nativo de Alaska;...
#
#
#                                                NHPI*
# 0                                             0,07 %
# 1                                             0,01 %
# 2                                             0,07 %
# 3                                             0,01 %
# 4                                             2,25 %
# 5                                             3,93 %
# 6                                            -5,82 %
# 7  * AIAN es nativo americano o nativo de Alaska;...

# %% [markdown]
# ## <font color=#33A5FF>****2. Funciones básicas de lectura de ficheros****<tfont>

# %% [markdown]
# **index_col** = Cambiar el índice

# %%
# Opción index_col
df = pd.read_excel('titanic.xlsx', engine='openpyxl', index_col=5)
# Seleccionamos el indice por su posicion, empezando por el 0 desde la izda.
df
# Out:
#       Id_Pasajero  Survived  Clase  \
# Edad
# 22.0            1         0      3
# 38.0            2         1      1
# 26.0            3         1      3
# 35.0            4         1      1
# 35.0            5         0      3
# ...           ...       ...    ...
# 27.0          887         0      2
# 19.0          888         1      1
# NaN           889         0      3
# 26.0          890         1      1
# 32.0          891         0      3
#
#                                                  Nombre       Sexo  \
# Edad
# 22.0                            Braund, Mr. Owen Harris  Masculino
# 38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino
# 26.0                             Heikkinen, Miss. Laina   Femenino
# 35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino
# 35.0                           Allen, Mr. William Henry  Masculino
# ...                                                 ...        ...
# 27.0                              Montvila, Rev. Juozas  Masculino
# 19.0                       Graham, Miss. Margaret Edith   Femenino
# NaN            Johnston, Miss. Catherine Helen "Carrie"   Femenino
# 26.0                              Behr, Mr. Karl Howell  Masculino
# 32.0                                Dooley, Mr. Patrick  Masculino
#
#       Familiares           Tiquete  Tarifa Cabina Embarcado
# Edad
# 22.0           0         A/5 21171    7.25    NaN         S
# 38.0           0          PC 17599   71.28    C85         C
# 26.0           0  STON/O2. 3101282    7.93    NaN         S
# 35.0           0            113803   53.10   C123         S
# 35.0           0            373450    8.05    NaN         S
# ...          ...               ...     ...    ...       ...
# 27.0           0            211536   13.00    NaN         S
# 19.0           0            112053   30.00    B42         S
# NaN            2        W./C. 6607   23.45    NaN         S
# 26.0           0            111369   30.00   C148         C
# 32.0           0            370376    7.75    NaN         Q
#
# [891 rows x 10 columns]

# %% [markdown]
# **nrows** = utilizar las n primeras filas

# %%
# Opción nrows
df = pd.read_excel('titanic.xlsx', engine='openpyxl', nrows=5)
df
# Out:
#    Id_Pasajero  Survived  Clase  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                               Nombre       Sexo  Edad  \
# 0                            Braund, Mr. Owen Harris  Masculino    22
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino    38
# 2                             Heikkinen, Miss. Laina   Femenino    26
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino    35
# 4                           Allen, Mr. William Henry  Masculino    35
#
#    Familiares           Tiquete  Tarifa Cabina Embarcado
# 0           0         A/5 21171    7.25    NaN         S
# 1           0          PC 17599   71.28    C85         C
# 2           0  STON/O2. 3101282    7.93    NaN         S
# 3           0            113803   53.10   C123         S
# 4           0            373450    8.05    NaN         S

# %% [markdown]
# **usecols**: Utilizar columnas específicas

# %%
# Opción usecols
# Le pasamos una lista con los nombres de las coumnas que queremos incluir en el df
df = pd.read_excel('titanic.xlsx', engine='openpyxl',
                   usecols=['Nombre', 'Sexo', 'Edad'])
df.head(10)
# Out:
#                                               Nombre       Sexo  Edad
# 0                            Braund, Mr. Owen Harris  Masculino  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino  38.0
# 2                             Heikkinen, Miss. Laina   Femenino  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino  35.0
# 4                           Allen, Mr. William Henry  Masculino  35.0
# 5                                   Moran, Mr. James  Masculino   NaN
# 6                            McCarthy, Mr. Timothy J  Masculino  54.0
# 7                     Palsson, Master. Gosta Leonard  Masculino   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   Femenino  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)   Femenino  14.0

# %% [markdown]
# **skiprows**: saltarse filas de abajo hacia arriba

# %%
# Opción skiprows
# Se le pasa un entero. Salta las filas que le pases. OJO, la fila 1 son los encabezados.
df = pd.read_excel('titanic.xlsx', engine='openpyxl', skiprows=3)
df
# Out:
#        3  1  3.1                        Heikkinen, Miss. Laina   Femenino  \
# 0      4  1    1  Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino
# 1      5  0    3                      Allen, Mr. William Henry  Masculino
# 2      6  0    3                              Moran, Mr. James  Masculino
# 3      7  0    1                       McCarthy, Mr. Timothy J  Masculino
# 4      8  0    3                Palsson, Master. Gosta Leonard  Masculino
# ..   ... ..  ...                                           ...        ...
# 883  887  0    2                         Montvila, Rev. Juozas  Masculino
# 884  888  1    1                  Graham, Miss. Margaret Edith   Femenino
# 885  889  0    3      Johnston, Miss. Catherine Helen "Carrie"   Femenino
# 886  890  1    1                         Behr, Mr. Karl Howell  Masculino
# 887  891  0    3                           Dooley, Mr. Patrick  Masculino
#
#        26  0 STON/O2. 3101282   7.93 Unnamed: 9  S
# 0    35.0  0           113803  53.10       C123  S
# 1    35.0  0           373450   8.05        NaN  S
# 2     NaN  0           330877   8.46        NaN  Q
# 3    54.0  0            17463  51.86        E46  S
# 4     2.0  1           349909  21.08        NaN  S
# ..    ... ..              ...    ...        ... ..
# 883  27.0  0           211536  13.00        NaN  S
# 884  19.0  0           112053  30.00        B42  S
# 885   NaN  2       W./C. 6607  23.45        NaN  S
# 886  26.0  0           111369  30.00       C148  C
# 887  32.0  0           370376   7.75        NaN  Q
#
# [888 rows x 11 columns]

# %% [markdown]
# **sheet_name**: Seleccionar las pestañas del libro excel

# %%
# Opción sheet_name
# Los files xlsx pueden contener varias hojas excell. Para acceder a ellas se usa esta funcion
# Le puedes pasar un numero de indice o el nombre de la hoja
df = pd.read_excel('titanic.xlsx', engine='openpyxl',
                   sheet_name=1)  # sheet_name='Pasajeros_2'
df
# Out:
#      Id_Pasajero  Survived  Clase  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      3
# 889          890         1      1
# 890          891         0      3
#
#                                                 Nombre       Sexo  Edad  \
# 0                              Braund, Mr. Owen Harris  Masculino  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino  38.0
# 2                               Heikkinen, Miss. Laina   Femenino  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino  35.0
# 4                             Allen, Mr. William Henry  Masculino  35.0
# ..                                                 ...        ...   ...
# 886                              Montvila, Rev. Juozas  Masculino  27.0
# 887                       Graham, Miss. Margaret Edith   Femenino  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   Femenino   NaN
# 889                              Behr, Mr. Karl Howell  Masculino  26.0
# 890                                Dooley, Mr. Patrick  Masculino  32.0
#
#      Familiares           Tiquete  Tarifa Cabina Embarcado
# 0             0         A/5 21171    7.25    NaN         S
# 1             0          PC 17599   71.28    C85         C
# 2             0  STON/O2. 3101282    7.93    NaN         S
# 3             0            113803   53.10   C123         S
# 4             0            373450    8.05    NaN         S
# ..          ...               ...     ...    ...       ...
# 886           0            211536   13.00    NaN         S
# 887           0            112053   30.00    B42         S
# 888           2        W./C. 6607   23.45    NaN         S
# 889           0            111369   30.00   C148         C
# 890           0            370376    7.75    NaN         Q
#
# [891 rows x 11 columns]

# %% [markdown]
# **header**: Se utiliza cuando las columnas no tienen encabezado

# %%
# Opción header
# ,header = None, lista = ['nombre', 'sexo']
df = pd.read_excel('titanic.xlsx', engine='openpyxl')
# Sirve para pasarle una lista con los nombres que quieres para los encabezados, como complemento de skiprows que nos
# devuelve el df sin encabezado

# %% [markdown]
# **parse_dates**: Para manejar series temporales

# %% [markdown]
# ## <font color=#33A5FF>****3. Funciones básicas de almacenamiento****<tfont>

# %%
# Ruta de la carpeta donde quiero guardar mis archivos exportados
ruta = '/home/michel/Documentos/Analisis/'

# %%
# Cargamos el file en una variable y lo modificamos al gusto
titanic = pd.read_excel('titanic.xlsx', nrows=25, usecols=[0, 2, 3, 4, 5, 7]) # nrows para numero de filas, usecols para que columnas incluir
titanic
# Out:
#     Id_Pasajero  Clase                                             Nombre  \
# 0             1      3                            Braund, Mr. Owen Harris
# 1             2      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2             3      3                             Heikkinen, Miss. Laina
# 3             4      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4             5      3                           Allen, Mr. William Henry
# 5             6      3                                   Moran, Mr. James
# 6             7      1                            McCarthy, Mr. Timothy J
# 7             8      3                     Palsson, Master. Gosta Leonard
# 8             9      3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9            10      2                Nasser, Mrs. Nicholas (Adele Achem)
# 10           11      3                    Sandstrom, Miss. Marguerite Rut
# 11           12      1                           Bonnell, Miss. Elizabeth
# 12           13      3                     Saundercock, Mr. William Henry
# 13           14      3                        Andersson, Mr. Anders Johan
# 14           15      3               Vestrom, Miss. Hulda Amanda Adolfina
# 15           16      2                   Hewlett, Mrs. (Mary D Kingcome)
# 16           17      3                               Rice, Master. Eugene
# 17           18      2                       Williams, Mr. Charles Eugene
# 18           19      3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19           20      3                            Masselmani, Mrs. Fatima
# 20           21      2                               Fynney, Mr. Joseph J
# 21           22      2                              Beesley, Mr. Lawrence
# 22           23      3                        McGowan, Miss. Anna "Annie"
# 23           24      1                       Sloper, Mr. William Thompson
# 24           25      3                      Palsson, Miss. Torborg Danira
#
#          Sexo  Edad           Tiquete
# 0   Masculino  22.0         A/5 21171
# 1    Femenino  38.0          PC 17599
# 2    Femenino  26.0  STON/O2. 3101282
# 3    Femenino  35.0            113803
# 4   Masculino  35.0            373450
# 5   Masculino   NaN            330877
# 6   Masculino  54.0             17463
# 7   Masculino   2.0            349909
# 8    Femenino  27.0            347742
# 9    Femenino  14.0            237736
# 10   Femenino   4.0           PP 9549
# 11   Femenino  58.0            113783
# 12  Masculino  20.0         A/5. 2151
# 13  Masculino  39.0            347082
# 14   Femenino  14.0            350406
# 15   Femenino  55.0            248706
# 16  Masculino   2.0            382652
# 17  Masculino   NaN            244373
# 18   Femenino  31.0            345763
# 19   Femenino   NaN              2649
# 20  Masculino  35.0            239865
# 21  Masculino  34.0            248698
# 22   Femenino  15.0            330923
# 23  Masculino  28.0            113788
# 24   Femenino   8.0            349909

# %%
# Exportar archivo formato excel
titanic.to_excel('titanic_export.xlsx')

# %%
# Exportar archivo formato excel sin índices
titanic.to_excel('titanic_export.xlsx', index=False) # index= en False para que no incluya indices por defecto

# %%
# Exportar archivo formato .csv
titanic.to_csv('titanic_export.csv', sep='|', index=False)

# %%
# Exportar archivo formato .txt
titanic.to_csv('titanic_export.txt', sep='|')

# %%
# Exportar archivo formato .html
titanic.to_html('titanic_export.html', index=False)
# Devuelve una tabla html

# %% [markdown]
# ## <font color=#33A5FF>****4. Explorando nuestro DataFrame****<tfont>

# %%
# Explorar datos opción dtypes
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
# Explorar datos opción shape
titanic.shape
# Out:
# (25, 6)

# %%
# Ver primeras filas datos opción head()
df.head()
# Out:
#    Id_Pasajero  Survived  Clase  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                               Nombre       Sexo  Edad  \
# 0                            Braund, Mr. Owen Harris  Masculino  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino  38.0
# 2                             Heikkinen, Miss. Laina   Femenino  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino  35.0
# 4                           Allen, Mr. William Henry  Masculino  35.0
#
#    Familiares           Tiquete  Tarifa Cabina Embarcado
# 0           0         A/5 21171    7.25    NaN         S
# 1           0          PC 17599   71.28    C85         C
# 2           0  STON/O2. 3101282    7.93    NaN         S
# 3           0            113803   53.10   C123         S
# 4           0            373450    8.05    NaN         S

# %%
# Ver últimas filas opción tail()
df.tail(15)
# Out:
#      Id_Pasajero  Survived  Clase  \
# 876          877         0      3
# 877          878         0      3
# 878          879         0      3
# 879          880         1      1
# 880          881         1      2
# 881          882         0      3
# 882          883         0      3
# 883          884         0      2
# 884          885         0      3
# 885          886         0      3
# 886          887         0      2
# 887          888         1      1
# 888          889         0      3
# 889          890         1      1
# 890          891         0      3
#
#                                             Nombre       Sexo  Edad  \
# 876                  Gustafsson, Mr. Alfred Ossian  Masculino  20.0
# 877                           Petroff, Mr. Nedelio  Masculino  19.0
# 878                             Laleff, Mr. Kristo  Masculino   NaN
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)   Femenino  56.0
# 880   Shelley, Mrs. William (Imanita Parrish Hall)   Femenino  25.0
# 881                             Markun, Mr. Johann  Masculino  33.0
# 882                   Dahlberg, Miss. Gerda Ulrika   Femenino  22.0
# 883                  Banfield, Mr. Frederick James  Masculino  28.0
# 884                         Sutehall, Mr. Henry Jr  Masculino  25.0
# 885           Rice, Mrs. William (Margaret Norton)   Femenino  39.0
# 886                          Montvila, Rev. Juozas  Masculino  27.0
# 887                   Graham, Miss. Margaret Edith   Femenino  19.0
# 888       Johnston, Miss. Catherine Helen "Carrie"   Femenino   NaN
# 889                          Behr, Mr. Karl Howell  Masculino  26.0
# 890                            Dooley, Mr. Patrick  Masculino  32.0
#
#      Familiares           Tiquete  Tarifa Cabina Embarcado
# 876           0              7534    9.85    NaN         S
# 877           0            349212    7.90    NaN         S
# 878           0            349217    7.90    NaN         S
# 879           1             11767   83.16    C50         C
# 880           1            230433   26.00    NaN         S
# 881           0            349257    7.90    NaN         S
# 882           0              7552   10.52    NaN         S
# 883           0  C.A./SOTON 34068   10.50    NaN         S
# 884           0   SOTON/OQ 392076    7.05    NaN         S
# 885           5            382652   29.13    NaN         Q
# 886           0            211536   13.00    NaN         S
# 887           0            112053   30.00    B42         S
# 888           2        W./C. 6607   23.45    NaN         S
# 889           0            111369   30.00   C148         C
# 890           0            370376    7.75    NaN         Q

# %%
# Ordenar datos por columnas
df = df[['Nombre', 'Tiquete', 'Tarifa', 'Cabina']]
df
# Out:
#                                                 Nombre           Tiquete  \
# 0                              Braund, Mr. Owen Harris         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2                               Heikkinen, Miss. Laina  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4                             Allen, Mr. William Henry            373450
# ..                                                 ...               ...
# 886                              Montvila, Rev. Juozas            211536
# 887                       Graham, Miss. Margaret Edith            112053
# 888           Johnston, Miss. Catherine Helen "Carrie"        W./C. 6607
# 889                              Behr, Mr. Karl Howell            111369
# 890                                Dooley, Mr. Patrick            370376
#
#      Tarifa Cabina
# 0      7.25    NaN
# 1     71.28    C85
# 2      7.93    NaN
# 3     53.10   C123
# 4      8.05    NaN
# ..      ...    ...
# 886   13.00    NaN
# 887   30.00    B42
# 888   23.45    NaN
# 889   30.00   C148
# 890    7.75    NaN
#
# [891 rows x 4 columns]
