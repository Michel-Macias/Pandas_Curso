# %% [markdown]
# # SELECCIÓN Y FILTRO DE DATOS DE UN DATAFRAME UTILIZANDO LA LIBRERÍA PANDAS
# ***
#
# En este notebook se explicarán los principales métodos filtros de datos utilizando las herramientas de la librería Pandas.
#
# [1. Lectura de archivos excel, csv, txt, html](#1.-Lectura-de-archivos-excel,-csv,-txt,-html)<br>
# [2. ¿Cómo selecciono un subconjunto de un DataFrame?](#2.-¿Cómo-selecciono-un-subconjunto-de-un-DataFrame?)<br>
# [3. ¿Cómo filtro filas específicas de un DataFrame?](#3.-¿Cómo-filtro-filas-específicas-de-un-DataFrame?)<br>
# [4. ¿Cómo selecciono filas y columnas específicas de un DataFrame?](#4.-¿Cómo-selecciono-filas-y-columnas-específicas-de-un-DataFrame?)<br>
# [5. Aprendiendo algunas funciones de pandas](#5.-Aprendiendo-algunas-funciones-de-pandas)<br>

# %%
# importar libreria
import pandas as pd
import xlrd
pd.__version__
# Out:
# '1.5.2'

# %% [markdown]
# ## <font color=#33A5FF>****1. Lectura de archivos excel, csv, txt, html****<tfont>

# %% [markdown]
# ### Descripción del las columnas del DataFrame

# %% [markdown]
# Para leer ficheros de excel puedes instalar en el anaconda Prom: **pip install xlrd**, seguido de ello puedes cargar el fichero titanic el cual contiene la siguiente información:

# %% [markdown]
# * **Id_Pasajero:** Id de cada pasajero.
#
# * **Survived:** esta característica tiene valor 0 y 1. 0 para no sobrevivido y 1 para sobrevivido.
#
# * **Clase:** Hay 3 clases: Clase 1, Clase 2 y Clase 3.
#
# * **Nombre:** Nombre del pasajero.
#
# * **Sexo:** Género del pasajero.
#
# * **Edad:** Edad del pasajero.
#
# * **Familiares:** numero de familiares del pasajero.
#
# * **Ticket:** Número de ticket del pasajero.
#
# * **Tarifa:** Indicando la tarifa.
#
# * **Cabina:** La cabina del pasajero.
#
# * **Embarcado:** La categoría embarcada.

# %% [markdown]
# Leer datos archivos excel con extensión **--->** .xls, .xlsx

# %%
# Cargar datos
df = pd.read_excel('titanic.xlsx', index_col=0)

# %%
df.head()
# Out:
#              Survived  Clase  \
# Id_Pasajero
# 1                   0      3
# 2                   1      1
# 3                   1      3
# 4                   1      1
# 5                   0      3
#
#                                                         Nombre       Sexo  \
# Id_Pasajero
# 1                                      Braund, Mr. Owen Harris  Masculino
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino
# 3                                       Heikkinen, Miss. Laina   Femenino
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino
# 5                                     Allen, Mr. William Henry  Masculino
#
#              Edad  Familiares           Tiquete  Tarifa Cabina Embarcado
# Id_Pasajero
# 1            22.0           0         A/5 21171    7.25    NaN         S
# 2            38.0           0          PC 17599   71.28    C85         C
# 3            26.0           0  STON/O2. 3101282    7.93    NaN         S
# 4            35.0           0            113803   53.10   C123         S
# 5            35.0           0            373450    8.05    NaN         S

# %% [markdown]
# ## <font color=#33A5FF>****2. ¿Cómo selecciono un subconjunto de un DataFrame?****<tfont>

# %% [markdown]
# ![image.png](attachment:71145035-6f25-4a13-8429-05d58059aabf.png)

# %%
# Seleccionando el nombre
df[['Nombre', 'Sexo']]
# Out:
#                                                         Nombre       Sexo
# Id_Pasajero
# 1                                      Braund, Mr. Owen Harris  Masculino
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino
# 3                                       Heikkinen, Miss. Laina   Femenino
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino
# 5                                     Allen, Mr. William Henry  Masculino
# ...                                                        ...        ...
# 887                                      Montvila, Rev. Juozas  Masculino
# 888                               Graham, Miss. Margaret Edith   Femenino
# 889                   Johnston, Miss. Catherine Helen "Carrie"   Femenino
# 890                                      Behr, Mr. Karl Howell  Masculino
# 891                                        Dooley, Mr. Patrick  Masculino
#
# [891 rows x 2 columns]

# %% [markdown]
# ## <font color=#33A5FF>****3. ¿Cómo filtro filas específicas de un DataFrame?****<tfont>

# %% [markdown]
# ![image.png](attachment:41e952fa-b878-4f21-9386-914378f68997.png)

# %%
# Seleccion de los hombres que abordaron el titanic
hombres = df[df['Sexo'] == 'Masculino']

# %%
hombres
# Out:
#              Survived  Clase                          Nombre       Sexo  Edad  \
# Id_Pasajero
# 1                   0      3         Braund, Mr. Owen Harris  Masculino  22.0
# 5                   0      3        Allen, Mr. William Henry  Masculino  35.0
# 6                   0      3                Moran, Mr. James  Masculino   NaN
# 7                   0      1         McCarthy, Mr. Timothy J  Masculino  54.0
# 8                   0      3  Palsson, Master. Gosta Leonard  Masculino   2.0
# ...               ...    ...                             ...        ...   ...
# 884                 0      2   Banfield, Mr. Frederick James  Masculino  28.0
# 885                 0      3          Sutehall, Mr. Henry Jr  Masculino  25.0
# 887                 0      2           Montvila, Rev. Juozas  Masculino  27.0
# 890                 1      1           Behr, Mr. Karl Howell  Masculino  26.0
# 891                 0      3             Dooley, Mr. Patrick  Masculino  32.0
#
#              Familiares           Tiquete  Tarifa Cabina Embarcado
# Id_Pasajero
# 1                     0         A/5 21171    7.25    NaN         S
# 5                     0            373450    8.05    NaN         S
# 6                     0            330877    8.46    NaN         Q
# 7                     0             17463   51.86    E46         S
# 8                     1            349909   21.08    NaN         S
# ...                 ...               ...     ...    ...       ...
# 884                   0  C.A./SOTON 34068   10.50    NaN         S
# 885                   0   SOTON/OQ 392076    7.05    NaN         S
# 887                   0            211536   13.00    NaN         S
# 890                   0            111369   30.00   C148         C
# 891                   0            370376    7.75    NaN         Q
#
# [577 rows x 10 columns]

# %%
hombres.shape
# Nos devuelve una tupla con las filas y las columnas, de esta manera sabemos que tenemos 577 filas (hombres)
# Out:
# (577, 10)

# %%
# Seleccion de las mujeres que abordaron el titanic
mujeres = df[df['Sexo'] == 'Femenino']

# %% [markdown]
# mujeres.shape

# %%
mujeres.head(10)
# Out:
#              Survived  Clase  \
# Id_Pasajero
# 2                   1      1
# 3                   1      3
# 4                   1      1
# 9                   1      3
# 10                  1      2
# 11                  1      3
# 12                  1      1
# 15                  0      3
# 16                  1      2
# 19                  0      3
#
#                                                         Nombre      Sexo  \
# Id_Pasajero
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  Femenino
# 3                                       Heikkinen, Miss. Laina  Femenino
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  Femenino
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  Femenino
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  Femenino
# 11                             Sandstrom, Miss. Marguerite Rut  Femenino
# 12                                    Bonnell, Miss. Elizabeth  Femenino
# 15                        Vestrom, Miss. Hulda Amanda Adolfina  Femenino
# 16                            Hewlett, Mrs. (Mary D Kingcome)   Femenino
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...  Femenino
#
#              Edad  Familiares           Tiquete  Tarifa Cabina Embarcado
# Id_Pasajero
# 2            38.0           0          PC 17599   71.28    C85         C
# 3            26.0           0  STON/O2. 3101282    7.93    NaN         S
# 4            35.0           0            113803   53.10   C123         S
# 9            27.0           2            347742   11.13    NaN         S
# 10           14.0           0            237736   30.07    NaN         C
# 11            4.0           1           PP 9549   16.70     G6         S
# 12           58.0           0            113783   26.55   C103         S
# 15           14.0           0            350406    7.85    NaN         S
# 16           55.0           0            248706   16.00    NaN         S
# 19           31.0           0            345763   18.00    NaN         S

# %%
# Persona con mas de 30 años que abordaron el
mas_30 = df[df['Edad'] > 30]

# %%
mas_30.shape
# Out:
# (305, 10)

# %%
mas_30.head()
# Out:
#              Survived  Clase  \
# Id_Pasajero
# 2                   1      1
# 4                   1      1
# 5                   0      3
# 7                   0      1
# 12                  1      1
#
#                                                         Nombre       Sexo  \
# Id_Pasajero
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino
# 5                                     Allen, Mr. William Henry  Masculino
# 7                                      McCarthy, Mr. Timothy J  Masculino
# 12                                    Bonnell, Miss. Elizabeth   Femenino
#
#              Edad  Familiares   Tiquete  Tarifa Cabina Embarcado
# Id_Pasajero
# 2            38.0           0  PC 17599   71.28    C85         C
# 4            35.0           0    113803   53.10   C123         S
# 5            35.0           0    373450    8.05    NaN         S
# 7            54.0           0     17463   51.86    E46         S
# 12           58.0           0    113783   26.55   C103         S

# %%
# Personas que tienen justo 49 años
clase = df[df['Edad'].isin([18, 33, 49])]
clase.head(10)
# Out:
#              Survived  Clase  \
# Id_Pasajero
# 39                  0      3
# 50                  0      3
# 53                  1      1
# 86                  1      3
# 104                 0      3
# 131                 0      3
# 145                 0      2
# 176                 0      3
# 205                 1      3
# 229                 0      2
#
#                                                         Nombre       Sexo  \
# Id_Pasajero
# 39                          Vander Planke, Miss. Augusta Maria   Femenino
# 50               Arnold-Franchi, Mrs. Josef (Josefine Franchi)   Femenino
# 53                    Harper, Mrs. Henry Sleeper (Myna Haxtun)   Femenino
# 86           Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...   Femenino
# 104                                 Johansson, Mr. Gustaf Joel  Masculino
# 131                                       Drazenoic, Mr. Jozef  Masculino
# 145                                 Andrew, Mr. Edgardo Samuel  Masculino
# 176                                     Klasen, Mr. Klas Albin  Masculino
# 205                                   Cohen, Mr. Gurshon "Gus"  Masculino
# 229                                  Fahlstrom, Mr. Arne Jonas  Masculino
#
#              Edad  Familiares   Tiquete  Tarifa Cabina Embarcado
# Id_Pasajero
# 39           18.0           0    345764   18.00    NaN         S
# 50           18.0           0    349237   17.80    NaN         S
# 53           49.0           0  PC 17572   76.73    D33         C
# 86           33.0           0   3101278   15.85    NaN         S
# 104          33.0           0      7540    8.65    NaN         S
# 131          33.0           0    349241    7.90    NaN         C
# 145          18.0           0    231945   11.50    NaN         S
# 176          18.0           1    350404    7.85    NaN         S
# 205          18.0           0  A/5 3540    8.05    NaN         S
# 229          18.0           0    236171   13.00    NaN         S

# %%
clase.shape
# Out:
# (47, 10)

# %%
# Personas que no registraron su edad al abordar el barco 
sin_cabina = df[df['Cabina'].notna()]

# %%
sin_cabina
# Out:
#              Survived  Clase  \
# Id_Pasajero
# 2                   1      1
# 4                   1      1
# 7                   0      1
# 11                  1      3
# 12                  1      1
# ...               ...    ...
# 872                 1      1
# 873                 0      1
# 880                 1      1
# 888                 1      1
# 890                 1      1
#
#                                                         Nombre       Sexo  \
# Id_Pasajero
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino
# 7                                      McCarthy, Mr. Timothy J  Masculino
# 11                             Sandstrom, Miss. Marguerite Rut   Femenino
# 12                                    Bonnell, Miss. Elizabeth   Femenino
# ...                                                        ...        ...
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)   Femenino
# 873                                   Carlsson, Mr. Frans Olof  Masculino
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)   Femenino
# 888                               Graham, Miss. Margaret Edith   Femenino
# 890                                      Behr, Mr. Karl Howell  Masculino
#
#              Edad  Familiares   Tiquete  Tarifa       Cabina Embarcado
# Id_Pasajero
# 2            38.0           0  PC 17599   71.28          C85         C
# 4            35.0           0    113803   53.10         C123         S
# 7            54.0           0     17463   51.86          E46         S
# 11            4.0           1   PP 9549   16.70           G6         S
# 12           58.0           0    113783   26.55         C103         S
# ...           ...         ...       ...     ...          ...       ...
# 872          47.0           1     11751   52.55          D35         S
# 873          33.0           0       695    5.00  B51 B53 B55         S
# 880          56.0           1     11767   83.16          C50         C
# 888          19.0           0    112053   30.00          B42         S
# 890          26.0           0    111369   30.00         C148         C
#
# [204 rows x 10 columns]

# %% [markdown]
# ## <font color=#33A5FF>****4. ¿Cómo selecciono filas y columnas específicas de un DataFrame?****<tfont>

# %% [markdown]
# ![image.png](attachment:4cf9f133-dac5-4fbd-84ec-95b5e91521a4.png)

# %%
# Me interesan los nombres de los pasajeros mayores de 30 años
nom_mas30 = df.loc[df['Edad'] > 30, ['Nombre']]

# %%
nom_mas30.head(10)
# Out:
#                                                         Nombre
# Id_Pasajero
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                     Allen, Mr. William Henry
# 7                                      McCarthy, Mr. Timothy J
# 12                                    Bonnell, Miss. Elizabeth
# 14                                 Andersson, Mr. Anders Johan
# 16                            Hewlett, Mrs. (Mary D Kingcome)
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 21                                        Fynney, Mr. Joseph J
# 22                                       Beesley, Mr. Lawrence

# %%
# Me interesan las filas 0 a 10 y las columnas 2 a 6.
df.iloc[0:11, 2:7]
# Out:
#                                                         Nombre       Sexo  \
# Id_Pasajero
# 1                                      Braund, Mr. Owen Harris  Masculino
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino
# 3                                       Heikkinen, Miss. Laina   Femenino
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino
# 5                                     Allen, Mr. William Henry  Masculino
# 6                                             Moran, Mr. James  Masculino
# 7                                      McCarthy, Mr. Timothy J  Masculino
# 8                               Palsson, Master. Gosta Leonard  Masculino
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   Femenino
# 10                         Nasser, Mrs. Nicholas (Adele Achem)   Femenino
# 11                             Sandstrom, Miss. Marguerite Rut   Femenino
#
#              Edad  Familiares           Tiquete
# Id_Pasajero
# 1            22.0           0         A/5 21171
# 2            38.0           0          PC 17599
# 3            26.0           0  STON/O2. 3101282
# 4            35.0           0            113803
# 5            35.0           0            373450
# 6             NaN           0            330877
# 7            54.0           0             17463
# 8             2.0           1            349909
# 9            27.0           2            347742
# 10           14.0           0            237736
# 11            4.0           1           PP 9549

# %%
df
# Out:
#              Survived  Clase  \
# Id_Pasajero
# 1                   0      3
# 2                   1      1
# 3                   1      3
# 4                   1      1
# 5                   0      3
# ...               ...    ...
# 887                 0      2
# 888                 1      1
# 889                 0      3
# 890                 1      1
# 891                 0      3
#
#                                                         Nombre       Sexo  \
# Id_Pasajero
# 1                                      Braund, Mr. Owen Harris  Masculino
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   Femenino
# 3                                       Heikkinen, Miss. Laina   Femenino
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   Femenino
# 5                                     Allen, Mr. William Henry  Masculino
# ...                                                        ...        ...
# 887                                      Montvila, Rev. Juozas  Masculino
# 888                               Graham, Miss. Margaret Edith   Femenino
# 889                   Johnston, Miss. Catherine Helen "Carrie"   Femenino
# 890                                      Behr, Mr. Karl Howell  Masculino
# 891                                        Dooley, Mr. Patrick  Masculino
#
#              Edad  Familiares           Tiquete  Tarifa Cabina Embarcado
# Id_Pasajero
# 1            22.0           0         A/5 21171    7.25    NaN         S
# 2            38.0           0          PC 17599   71.28    C85         C
# 3            26.0           0  STON/O2. 3101282    7.93    NaN         S
# 4            35.0           0            113803   53.10   C123         S
# 5            35.0           0            373450    8.05    NaN         S
# ...           ...         ...               ...     ...    ...       ...
# 887          27.0           0            211536   13.00    NaN         S
# 888          19.0           0            112053   30.00    B42         S
# 889           NaN           2        W./C. 6607   23.45    NaN         S
# 890          26.0           0            111369   30.00   C148         C
# 891          32.0           0            370376    7.75    NaN         Q
#
# [891 rows x 10 columns]

# %% [markdown]
# ## <font color=#33A5FF>****5. Aprendiendo algunas funciones de pandas****<tfont>

# %%
# Valor promedio de la edad de los pasajeros
df['Edad'].mean()
# Out:
# 29.69911764705882

# %%
# Pasajeros mujeres con mayor edad que abordaron el titanic
df[df['Sexo']=='Femenino'].max()
# Out:
# /tmp/ipykernel_7703/2545582650.py:2: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df['Sexo']=='Femenino'].max()
# Survived                                                 1
# Clase                                                    3
# Nombre        de Messemaeker, Mrs. Guillaume Joseph (Emma)
# Sexo                                              Femenino
# Edad                                                  63.0
# Familiares                                               6
# Tiquete                                          WE/P 5735
# Tarifa                                              512.33
# dtype: object

# %%
# Pasajeros mujeres con menor edad que abordaron el titanic
df[df['Sexo'] == 'Femenino'].min()
# Out:
# /tmp/ipykernel_7703/3727681621.py:2: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df['Sexo'] == 'Femenino'].min()
# Survived                                     0
# Clase                                        1
# Nombre        Abbott, Mrs. Stanton (Rosa Hunt)
# Sexo                                  Femenino
# Edad                                      0.75
# Familiares                                   0
# Tiquete                                 110152
# Tarifa                                    6.75
# dtype: object

# %%
# Número total de pasajeros registrados en el titanic
len(df)
# Out:
# 891
